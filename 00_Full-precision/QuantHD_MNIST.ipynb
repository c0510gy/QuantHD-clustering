# %%
import sys
sys.path.append('../')
import clustering_tester
from tqdm.notebook import tqdm

# %%
DIM = 10000
MAX_SAMPLES = 10000
EPOCHS = 40

# %%
histories = []
for trial in tqdm(range(10)):
  history = clustering_tester.run_clustering_fullprecision(
    *clustering_tester.get_mnist_dataset(MAX_SAMPLES),
    DIM,
    EPOCHS,
  )
  histories.append(history)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Loading dataset mnist from mnist
# Loading train data... train data of shape (60000, 784) loaded
# Loading test data...  test  data of shape (10000, 784) loaded
# Data Loaded. Num of features = 784 Num of Classes = 10
# selected initial labels: [0, 0, 0, 1, 2, 3, 3, 4, 7, 7]
# 0.6322
# Loading dataset mnist from mnist
# Loading train data... train data of shape (60000, 784) loaded
# Loading test data...  test  data of shape (10000, 784) loaded
# Data Loaded. Num of features = 784 Num of Classes = 10
# selected initial labels: [0, 1, 1, 1, 2, 3, 6, 7, 7, 7]
# 0.6537
# Loading dataset mnist from mnist
# Loading train data... train data of shape (60000, 784) loaded
# Loading test data...  test  data of shape (10000, 784) loaded
# Data Loaded. Num of features = 784 Num of Classes = 10
# selected initial labels: [1, 3, 4, 4, 4, 4, 5, 5, 6, 8]
# 0.6112
# Loading dataset mnist from mnist
# Loading train data... train data of shape (60000, 784) loaded
# Loading test data...  test  data of shape (10000, 784) loaded
# Data Loaded. Num of features = 784 Num of Classes = 10
# selected initial labels: [0, 1, 1, 1, 4, 4, 5, 7, 7, 7]
# 0.5838
# Loading dataset mnist from mnist
# Loading train data... train data of shape (60000, 784) loaded
# Loading test data...  test  data of shape (10000, 784) loaded
# Data Loaded. Num of features = 784 Num of Classes = 10
# selected initial labels: [0, 1, 2, 2, 3, 3, 4, 7, 8, 9]
# 0.6563
# Loading dataset mnist from mnist
# Loading train data... train data of shape (60000, 784) loaded
# Loading test data...  test  data of shape (10000, 784) loaded
# Data Loaded. Num of features = 784 Num of Classes = 10
# selected initial labels: [0, 1, 2, 3, 3, 6, 6, 7, 8, 8]
# 0.5952
# Loading dataset mnist from mnist
# Loading train data... train data of shape (60000, 784) loaded
# Loading test data...  test  data of shape (10000, 784) loaded
# Data Loaded. Num of features = 784 Num of Classes = 10
# selected initial labels: [0, 2, 3, 3, 5, 6, 6, 7, 9, 9]
# 0.615
# Loading dataset mnist from mnist
# Loading train data... train data of shape (60000, 784) loaded
# Loading test data...  test  data of shape (10000, 784) loaded
# Data Loaded. Num of features = 784 Num of Classes = 10
# selected initial labels: [0, 2, 4, 5, 5, 6, 7, 8, 9, 9]
# 0.6066
# Loading dataset mnist from mnist
# Loading train data... train data of shape (60000, 784) loaded
# Loading test data...  test  data of shape (10000, 784) loaded
# Data Loaded. Num of features = 784 Num of Classes = 10
# selected initial labels: [0, 0, 1, 2, 3, 5, 7, 7, 7, 8]
# 0.6253
# Loading dataset mnist from mnist
# Loading train data... train data of shape (60000, 784) loaded
# Loading test data...  test  data of shape (10000, 784) loaded
# Data Loaded. Num of features = 784 Num of Classes = 10
# selected initial labels: [0, 1, 1, 2, 2, 4, 4, 5, 7, 7]
# 0.592

# %%
clustering_tester.plot_histories(histories)
