# %%
import sys
sys.path.append('../')
import clustering_tester
from tqdm.notebook import tqdm

# %%
DIM = 10000
MAX_SAMPLES = 10000
EPOCHS = 40

# %%
histories = []
for trial in tqdm(range(10)):
  history = clustering_tester.run_clustering_fullprecision(
    *clustering_tester.get_iris_dataset(MAX_SAMPLES),
    DIM,
    EPOCHS,
    plot=True,
  )
  histories.append(history)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# selected initial labels: [0, 1, 1]
# 0.14666666666666667
# selected initial labels: [0, 1, 2]
# 0.2733333333333333
# selected initial labels: [1, 1, 2]
# 0.5266666666666666
# selected initial labels: [0, 0, 2]
# 0.44
# selected initial labels: [1, 2, 2]
# 0.30666666666666664
# selected initial labels: [0, 1, 2]
# 0.006666666666666667
# selected initial labels: [0, 1, 1]
# 0.32666666666666666
# selected initial labels: [0, 1, 1]
# 0.32666666666666666
# selected initial labels: [0, 1, 1]
# 0.12666666666666668
# selected initial labels: [0, 1, 2]
# 0.1

# %%
clustering_tester.plot_histories(histories)
