# %%
import sys
sys.path.append('../')
import clustering_tester
from tqdm.notebook import tqdm

# %%
DIM = 10000
MAX_SAMPLES = 10000
EPOCHS = 40

# %%
histories = []
for trial in tqdm(range(10)):
  history = clustering_tester.run_clustering_fullprecision(
    *clustering_tester.get_isolet_dataset(MAX_SAMPLES),
    DIM,
    EPOCHS,
  )
  histories.append(history)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Loading dataset isolet from isolet
# Loading train data... train data of shape (6238, 617) loaded
# Loading test data...  test  data of shape (1559, 617) loaded
# Data Loaded. Num of features = 617 Num of Classes = 26/Users/sang-geon/git_reps/QuantHD-clustering/00_Full-precision/../hd_clustering/encoder.py:61: UserWarning: An output with one or more elements was resized since it had shape [63, 10000], which does not match the required output shape [1, 10000].This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at  /Users/distiller/project/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.matmul(x[i:i+bsize], self.basis.T, out=temp)
# selected initial labels: [0, 1, 2, 2, 8, 10, 11, 12, 13, 15, 15, 15, 16, 16, 17, 18, 18, 19, 21, 22, 22, 23, 24, 24, 25, 25]
# 0.5631612696377044
# Loading dataset isolet from isolet
# Loading train data... train data of shape (6238, 617) loaded
# Loading test data...  test  data of shape (1559, 617) loaded
# Data Loaded. Num of features = 617 Num of Classes = 26/Users/sang-geon/git_reps/QuantHD-clustering/00_Full-precision/../hd_clustering/encoder.py:61: UserWarning: An output with one or more elements was resized since it had shape [63, 10000], which does not match the required output shape [1, 10000].This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at  /Users/distiller/project/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.matmul(x[i:i+bsize], self.basis.T, out=temp)
# selected initial labels: [2, 3, 4, 4, 5, 7, 8, 8, 9, 10, 10, 10, 14, 14, 14, 15, 16, 16, 17, 18, 18, 19, 20, 20, 20, 23]
# 0.5755049695415198
# Loading dataset isolet from isolet
# Loading train data... train data of shape (6238, 617) loaded
# Loading test data...  test  data of shape (1559, 617) loaded
# Data Loaded. Num of features = 617 Num of Classes = 26/Users/sang-geon/git_reps/QuantHD-clustering/00_Full-precision/../hd_clustering/encoder.py:61: UserWarning: An output with one or more elements was resized since it had shape [63, 10000], which does not match the required output shape [1, 10000].This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at  /Users/distiller/project/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.matmul(x[i:i+bsize], self.basis.T, out=temp)
# selected initial labels: [0, 2, 3, 4, 4, 4, 5, 7, 7, 7, 9, 11, 11, 11, 13, 14, 15, 17, 17, 18, 20, 22, 22, 22, 22, 23]
# 0.5184353959602437
# Loading dataset isolet from isolet
# Loading train data... train data of shape (6238, 617) loaded
# Loading test data...  test  data of shape (1559, 617) loaded
# Data Loaded. Num of features = 617 Num of Classes = 26/Users/sang-geon/git_reps/QuantHD-clustering/00_Full-precision/../hd_clustering/encoder.py:61: UserWarning: An output with one or more elements was resized since it had shape [63, 10000], which does not match the required output shape [1, 10000].This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at  /Users/distiller/project/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.matmul(x[i:i+bsize], self.basis.T, out=temp)
# selected initial labels: [0, 2, 2, 4, 7, 8, 9, 10, 12, 12, 14, 14, 15, 16, 17, 18, 20, 21, 21, 21, 22, 22, 22, 23, 24, 25]
# 0.6069252965694133
# Loading dataset isolet from isolet
# Loading train data... train data of shape (6238, 617) loaded
# Loading test data...  test  data of shape (1559, 617) loaded
# Data Loaded. Num of features = 617 Num of Classes = 26/Users/sang-geon/git_reps/QuantHD-clustering/00_Full-precision/../hd_clustering/encoder.py:61: UserWarning: An output with one or more elements was resized since it had shape [63, 10000], which does not match the required output shape [1, 10000].This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at  /Users/distiller/project/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.matmul(x[i:i+bsize], self.basis.T, out=temp)
# selected initial labels: [0, 1, 3, 4, 5, 5, 7, 8, 8, 10, 11, 15, 16, 16, 17, 18, 19, 21, 21, 21, 22, 22, 24, 25, 25, 25]
# 0.5952228278294325
# Loading dataset isolet from isolet
# Loading train data... train data of shape (6238, 617) loaded
# Loading test data...  test  data of shape (1559, 617) loaded
# Data Loaded. Num of features = 617 Num of Classes = 26/Users/sang-geon/git_reps/QuantHD-clustering/00_Full-precision/../hd_clustering/encoder.py:61: UserWarning: An output with one or more elements was resized since it had shape [63, 10000], which does not match the required output shape [1, 10000].This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at  /Users/distiller/project/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.matmul(x[i:i+bsize], self.basis.T, out=temp)
# selected initial labels: [0, 4, 4, 4, 5, 7, 8, 8, 9, 9, 9, 10, 13, 14, 14, 16, 17, 17, 17, 19, 22, 23, 24, 25, 25, 25]
# 0.5747034305867265
# Loading dataset isolet from isolet
# Loading train data... train data of shape (6238, 617) loaded
# Loading test data...  test  data of shape (1559, 617) loaded
# Data Loaded. Num of features = 617 Num of Classes = 26/Users/sang-geon/git_reps/QuantHD-clustering/00_Full-precision/../hd_clustering/encoder.py:61: UserWarning: An output with one or more elements was resized since it had shape [63, 10000], which does not match the required output shape [1, 10000].This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at  /Users/distiller/project/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.matmul(x[i:i+bsize], self.basis.T, out=temp)
# selected initial labels: [0, 1, 1, 2, 2, 3, 4, 6, 7, 7, 9, 9, 10, 11, 11, 12, 12, 12, 13, 14, 16, 19, 19, 23, 24, 24]
# 0.6019557550496955
# Loading dataset isolet from isolet
# Loading train data... train data of shape (6238, 617) loaded
# Loading test data...  test  data of shape (1559, 617) loaded
# Data Loaded. Num of features = 617 Num of Classes = 26/Users/sang-geon/git_reps/QuantHD-clustering/00_Full-precision/../hd_clustering/encoder.py:61: UserWarning: An output with one or more elements was resized since it had shape [63, 10000], which does not match the required output shape [1, 10000].This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at  /Users/distiller/project/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.matmul(x[i:i+bsize], self.basis.T, out=temp)
# selected initial labels: [0, 1, 4, 4, 7, 8, 9, 11, 12, 15, 16, 16, 16, 18, 19, 19, 20, 21, 21, 22, 22, 23, 24, 24, 24, 24]
# 0.5969862135299776
# Loading dataset isolet from isolet
# Loading train data... train data of shape (6238, 617) loaded
# Loading test data...  test  data of shape (1559, 617) loaded
# Data Loaded. Num of features = 617 Num of Classes = 26/Users/sang-geon/git_reps/QuantHD-clustering/00_Full-precision/../hd_clustering/encoder.py:61: UserWarning: An output with one or more elements was resized since it had shape [63, 10000], which does not match the required output shape [1, 10000].This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at  /Users/distiller/project/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.matmul(x[i:i+bsize], self.basis.T, out=temp)
# selected initial labels: [3, 4, 5, 9, 9, 10, 10, 11, 13, 14, 14, 15, 16, 16, 17, 19, 20, 20, 21, 21, 22, 22, 22, 23, 23, 25]
# 0.5482526450785509
# Loading dataset isolet from isolet
# Loading train data... train data of shape (6238, 617) loaded
# Loading test data...  test  data of shape (1559, 617) loaded
# Data Loaded. Num of features = 617 Num of Classes = 26/Users/sang-geon/git_reps/QuantHD-clustering/00_Full-precision/../hd_clustering/encoder.py:61: UserWarning: An output with one or more elements was resized since it had shape [63, 10000], which does not match the required output shape [1, 10000].This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at  /Users/distiller/project/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.matmul(x[i:i+bsize], self.basis.T, out=temp)
# selected initial labels: [0, 0, 1, 3, 3, 5, 7, 8, 8, 9, 10, 11, 11, 12, 12, 16, 18, 20, 21, 21, 22, 22, 22, 23, 24, 25]
# 0.627124078230202

# %%
clustering_tester.plot_histories(histories)
