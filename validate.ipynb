# %%
import matplotlib.pyplot as plt
import numpy as np
import json
import clustering_tester

# %%
DIM = 10000
MAX_SAMPLES = 10000
BITS = 3
EPOCHS = 30

# %%
clustering_tester.DATA_LOC = './Conventional_Data/'

# %%
clustering_tester.run_clustering_validation(
  *clustering_tester.get_mnist_dataset(MAX_SAMPLES),
  BITS,
  DIM,
  EPOCHS,
  clustering_tester.get_prob_tables_from_json('./prob_table.json')['27C_Front_3nm_3bit'],
)
# Out:
# Loading dataset mnist from mnist
# Loading train data... train data of shape (60000, 784) loaded
# Loading test data...  test  data of shape (10000, 784) loaded
# Data Loaded. Num of features = 784 Num of Classes = 10
# unique classes: 10
# selected initial labels: [0, 1, 1, 1, 4, 6, 6, 7, 8, 9]
# /Users/sang-geon/git_reps/QuantHD-clustering/venv/lib/python3.8/site-packages/scipy/stats/_stats_py.py:2579: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /Users/distiller/project/pytorch/torch/csrc/utils/tensor_numpy.cpp:178.)
#   z[np.broadcast_to(isconst, z.shape)] = np.nan
# =========================================
# Original [2. 1. 5. ... 1. 1. 4.]
# Flipped [2. 2. 6. ... 0. 0. 5.]
# % of symbols flipped 39.07
# =========================================
# =========================================
# Original [2. 2. 1. ... 3. 1. 3.]
# Flipped [3. 2. 0. ... 3. 0. 3.]
# % of symbols flipped 39.019999999999996
# =========================================
# =========================================
# Original [2. 2. 2. ... 3. 0. 3.]
# Flipped [2. 2. 2. ... 4. 0. 2.]
# % of symbols flipped 38.72
# =========================================
# =========================================
# Original [4. 1. 2. ... 1. 0. 1.]
# Flipped [4. 0. 3. ... 2. 0. 1.]
# % of symbols flipped 38.190000000000005
# =========================================
# =========================================
# Original [4. 1. 3. ... 3. 3. 5.]
# Flipped [3. 1. 3. ... 3. 2. 6.]
# % of symbols flipped 39.36
# =========================================
# =========================================
# Original [2. 1. 5. ... 1. 2. 5.]
# Flipped [1. 2. 5. ... 1. 2. 5.]
# % of symbols flipped 38.080000000000005
# =========================================
# =========================================
# Original [4. 1. 2. ... 2. 0. 1.]
# Flipped [4. 2. 2. ... 2. 0. 2.]
# % of symbols flipped 38.379999999999995
# =========================================
# =========================================
# Original [2. 2. 1. ... 3. 1. 3.]
# Flipped [1. 2. 1. ... 3. 1. 2.]
# % of symbols flipped 39.1
# =========================================
# =========================================
# Original [2. 2. 1. ... 3. 1. 3.]
# Flipped [2. 2. 0. ... 3. 1. 3.]
# % of symbols flipped 38.51
# =========================================
# =========================================
# Original [4. 1. 2. ... 2. 0. 1.]
# Flipped [4. 1. 1. ... 2. 0. 0.]
# % of symbols flipped 38.85
# =========================================
# =========================================
# Original [2. 2. 1. ... 3. 1. 3.]
# Flipped [2. 2. 1. ... 2. 2. 3.]
# % of symbols flipped 38.96
# =========================================
# =========================================
# Original [2. 2. 1. ... 3. 1. 3.]
# Flipped [2. 2. 2. ... 2. 2. 3.]
# % of symbols flipped 39.43
# =========================================
# =========================================
# Original [3. 2. 3. ... 1. 0. 2.]
# Flipped [3. 3. 2. ... 1. 0. 2.]
# % of symbols flipped 38.51
# =========================================
# =========================================
# Original [2. 1. 5. ... 1. 2. 5.]
# Flipped [1. 0. 5. ... 1. 3. 5.]
# % of symbols flipped 39.81
# =========================================
# =========================================
# Original [1. 2. 2. ... 3. 0. 3.]
# Flipped [0. 3. 2. ... 2. 0. 4.]
# % of symbols flipped 38.66
# =========================================
# =========================================
# Original [2. 2. 3. ... 2. 0. 2.]
# Flipped [2. 3. 3. ... 2. 0. 2.]
# % of symbols flipped 38.42
# =========================================
# =========================================
# Original [1. 2. 3. ... 2. 0. 4.]
# Flipped [1. 2. 3. ... 2. 0. 3.]
# % of symbols flipped 38.95
# =========================================
# =========================================
# Original [2. 3. 2. ... 2. 0. 3.]
# Flipped [3. 2. 3. ... 2. 0. 3.]
# % of symbols flipped 37.76
# =========================================
# =========================================
# Original [1. 2. 3. ... 1. 1. 4.]
# Flipped [1. 3. 4. ... 2. 1. 3.]
# % of symbols flipped 37.81
# =========================================
# =========================================
# Original [2. 1. 5. ... 1. 2. 5.]
# Flipped [3. 1. 6. ... 2. 2. 5.]
# % of symbols flipped 38.47
# =========================================
# =========================================
# Original [2. 3. 2. ... 2. 0. 3.]
# Flipped [3. 3. 3. ... 1. 0. 3.]
# % of symbols flipped 38.86
# =========================================
# =========================================
# Original [1. 2. 2. ... 3. 0. 3.]
# Flipped [2. 1. 1. ... 3. 0. 3.]
# % of symbols flipped 39.09
# =========================================
# =========================================
# Original [1. 2. 3. ... 1. 0. 4.]
# Flipped [0. 1. 3. ... 0. 0. 4.]
# % of symbols flipped 38.39
# =========================================
# =========================================
# Original [3. 2. 3. ... 1. 0. 2.]
# Flipped [3. 2. 3. ... 1. 0. 2.]
# % of symbols flipped 39.28
# =========================================
# =========================================
# Original [1. 2. 3. ... 1. 0. 4.]
# Flipped [2. 1. 3. ... 1. 0. 4.]
# % of symbols flipped 38.519999999999996
# =========================================
# =========================================
# Original [1. 2. 2. ... 3. 0. 3.]
# Flipped [1. 3. 2. ... 3. 0. 4.]
# % of symbols flipped 39.24
# =========================================
# =========================================
# Original [2. 3. 2. ... 2. 0. 3.]
# Flipped [2. 3. 3. ... 3. 0. 3.]
# % of symbols flipped 37.79
# =========================================
# =========================================
# Original [1. 2. 3. ... 2. 1. 4.]
# Flipped [1. 2. 4. ... 2. 1. 4.]
# % of symbols flipped 38.3
# =========================================
# =========================================
# Original [4. 1. 2. ... 2. 0. 1.]
# Flipped [4. 0. 1. ... 2. 0. 2.]
# % of symbols flipped 39.410000000000004
# =========================================
# =========================================
# Original [2. 2. 1. ... 3. 1. 3.]
# Flipped [2. 2. 1. ... 3. 0. 4.]
# % of symbols flipped 38.53
# =========================================
# 0.6639
# [0.5153,
#  0.5359,
#  0.5577,
#  0.5738,
#  0.591,
#  0.6015,
#  0.612,
#  0.6174,
#  0.6225,
#  0.6286,
#  0.6334,
#  0.6375,
#  0.6412,
#  0.6471,
#  0.6496,
#  0.6525,
#  0.6529,
#  0.6555,
#  0.6573,
#  0.6584,
#  0.6608,
#  0.6626,
#  0.6623,
#  0.6607,
#  0.6637,
#  0.6628,
#  0.6626,
#  0.6639,
#  0.6622,
#  0.6639]
